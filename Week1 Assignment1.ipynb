# %% [markdown]
# list and array

# %%
import  numpy as np
lst1=[1,2,3]
array1=np.array(lst1)
print("list = ",lst1)
print("array = ",array1)
# Out:
# list =  [1, 2, 3]
# array =  [1 2 3]

# %%
import numpy as np
lst1=[1,2,3]
array1=np.array(lst1)
print("list = ",lst1)
print("array = ",array1)
type(lst1)
type(array1)
print(array1.ndim)
# Out:
# list =  [1, 2, 3]
# array =  [1 2 3]
# 1

# %% [markdown]
#  Perform mathematical operations on these datasets created - multiplication, division,
# powerof

# %%
import numpy as np
array1=np.array([10,20,30])
array2=np.array([2,2,2])
print("array2 multiplied by array1: ",array1*array2)
print("array2 divided by array1: ",array2/array1)
print("array2 raised to the power of array1: ",array2**array1)
# Out:
# array2 multiplied by array1:  [20 40 60]
# array2 divided by array1:  [0.2        0.1        0.06666667]
# array2 raised to the power of array1:  [      1024    1048576 1073741824]

# %% [markdown]
#  Combine text with Numpy fuction to generate a textual output - ”Addition of Two:
# array1 +array 2

# %%
import numpy as np


array1 = np.array([10,20,30])
array2 = np.array([2,2,2])
addition = array1 + array2
text1 = "sr"
text2 = "sumathi reddy"
combined_text = text1 + " " + text2
print("Addition of Two: ", addition)
print(combined_text)
# Out:
# Addition of Two:  [12 22 32]
# sr sumathi reddy

# %% [markdown]
# Implement np.sin(), log(), log2(), np.exp())

# %%
import numpy as np
array1=np.array([10,20,30])
#sine function
print("sine:.",np.log(array1))
#logarithm
print("natural logarithm: ",np.log(array1))
print("base-10 logarithm: ",np.log10(array1))
print("base-2 logarithm: ",np.log2(array1))
#exponential
print("exponential: ",np.exp(array1))
# Out:
# sine:. [2.30258509 2.99573227 3.40119738]
# natural logarithm:  [2.30258509 2.99573227 3.40119738]
# base-10 logarithm:  [1.         1.30103    1.47712125]
# base-2 logarithm:  [3.32192809 4.32192809 4.9068906 ]
# exponential:  [2.20264658e+04 4.85165195e+08 1.06864746e+13]

# %% [markdown]
# Generate a Data set for Health Care using the following:
# people = [’kiran’, arun’, ’vijay’, ’varun’]
# age =[25, 30, 35, 40, 45]
# height =[145, 151, 165, 173]
# weight=[45, 55, 65, 75]

# %% [markdown]
# **bar chart**

# %%
import matplotlib.pyplot as plt
people =["Kiran","Rosy","Jhonny","Rahul"]
age=[25,20,28,19]
weight=[55,65,58,60]
height=[160,135,150,165]
plt.scatter(weight,height)
plt.title("Relation b/w weight and height")
plt.ylabel("height in Meters")
plt.xlabel("Weight in Kgs ")
plt.show()
plt.scatter(age,weight)
plt.title("Relation b/w age and weight")
plt.ylabel("age in numbers")
plt.xlabel("weight in kgs")
plt.show()

# %%
plt.figure(figsize=(12,4))
plt.title("peple's weight in Kgs",fontsize=16,fontstyle='italic')
plt.bar(x=people,height=weight,width=0.6,color='darkred',edgecolor='k',alpha=0.6)
plt.xlabel("people",fontsize=15)
plt.ylabel("weight(in kgs)",fontsize=15)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.show()

# %%
 import numpy as np

plt.figure(figsize=(7,5))

# Main plot function 'hist'

plt.hist(weight, color='red', edgecolor='k', alpha=0.75,bins=5)

plt.title("Histogram of patient weight", fontsize=18)

plt.xlabel("Weight in kgs", fontsize=15)

plt.xticks(fontsize=15)

plt.yticks(fontsize=15)

plt.show()

# %%
import pandas as pd



data_excel = pd.read_excel('/haha3.xlsx')



data_csv = pd.read_csv('/haha.csv')


data_tsv = pd.read_csv('/haha2.tsv', sep='\t')

print(data_excel)

print(data_csv)

print(data_tsv)
# Out:
#           Table 1 Unnamed: 1  Unnamed: 2 Unnamed: 3
# 0           Name        Age        Ht no      Place
# 1       RajaRohan         19  2203A52126  Huzurabad
# 2  Vamshi krishna         19  2203A52127     Ambala
# 3         Avinash         19  2203A52227   Indurthi
# 4    Gopi krishna         21  2203A52076     Parkal
# 5          Sravan         19  2203A52099   Warangal
#             Name   Age        Ht no      Place  Unnamed: 4  Unnamed: 5
# 0       RajaRohan    19  2203A52126  Huzurabad         NaN         NaN
# 1  Vamshi krishna    19  2203A52127     Ambala         NaN         NaN
# 2         Avinash    19  2203A52227   Indurthi         NaN         NaN
# 3    Gopi krishna    21  2203A52076     Parkal         NaN         NaN
# 4          Sravan    19  2203A52099   Warangal         NaN         NaN
#             Name   Age        Ht no      Place  Unnamed: 4  Unnamed: 5
# 0       RajaRohan    19  2203A52126  Huzurabad         NaN         NaN
# ...
